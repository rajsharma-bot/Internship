# %% [markdown]
# # Used Car price Web Scraping

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.keys import Keys
import requests
import re
import time

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"chromedriver.exe")

# %% [markdown]
# # Ahmedabad

# %%
url1 = "https://www.cardekho.com/used-cars+in+ahmedabad"
driver.get(url1)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Ahmedabad'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df1 = pd.DataFrame({})
df1["name"] = name
df1["varient"] = varient
df1["engine"] = engine
df1["kilometers"] = kilometers
df1["car_type"] = car_type
df1["location"] = location
df1["year"]=year
df1["price"] = price

# %% [markdown]
# # Bangalore

# %%
url2 = "https://www.cardekho.com/used-cars+in+Bangalore"
driver.get(url2)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Bangalore'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df2 = pd.DataFrame({})
df2["name"] = name
df2["varient"] = varient
df2["engine"] = engine
df2["kilometers"] = kilometers
df2["car_type"] = car_type
df2["location"] = location
df2["year"]=year
df2["price"] = price

# %% [markdown]
# # Delhi NCR

# %%
url3 = "https://www.cardekho.com/used-cars+in+delhi-ncr"
driver.get(url3)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Delhi NCR'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df3 = pd.DataFrame({})
df3["name"] = name
df3["varient"] = varient
df3["engine"] = engine
df3["kilometers"] = kilometers
df3["car_type"] = car_type
df3["location"] = location
df3["year"]=year
df3["price"] = price

# %% [markdown]
# # Gurgaon

# %%
url4 = "https://www.cardekho.com/used-cars+in+gurgaon"
driver.get(url4)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Gurgaon'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df4 = pd.DataFrame({})
df4["name"] = name
df4["varient"] = varient
df4["engine"] = engine
df4["kilometers"] = kilometers
df4["car_type"] = car_type
df4["location"] = location
df4["year"]=year
df4["price"] = price

# %% [markdown]
# # Hyderabad

# %%
url5 = "https://www.cardekho.com/used-cars+in+hyderabad"
driver.get(url1)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Hyderabad'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements("//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df5 = pd.DataFrame({})
df5["name"] = name
df5["varient"] = varient
df5["engine"] = engine
df5["kilometers"] = kilometers
df5["car_type"] = car_type
df5["location"] = location
df5["year"]=year
df5["price"] = price

# %% [markdown]
# # Jaipur

# %%
url6 = "https://www.cardekho.com/used-cars+in+jaipur"
driver.get(url6)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Jaipur'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df6 = pd.DataFrame({})
df6["name"] = name
df6["varient"] = varient
df6["engine"] = engine
df6["kilometers"] = kilometers
df6["car_type"] = car_type
df6["location"] = location
df6["year"]=year
df6["price"] = price

# %% [markdown]
# # Kolkata

# %%
url7 = "https://www.cardekho.com/used-cars+in+kolkata"
driver.get(url7)
driver.maximize_window()
time.sleep(5)
for _ in range(100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
car_urls= []
url = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
for i in url:
    car_urls.append(i.get_attribute("href"))
len(car_urls)
#creating the empty lists
name = []
varient = []
engine = []
kilometers = []
car_type= []
owner = []
year = []
price = []
location='Kolkata'

for url in car_urls:
    driver.get(url)
    time.sleep(10)
    
    # fetching name of used cars
    try:
        names = driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-12']/h1")
        for j in names:
            name.append(j.text)
        
    except NoSuchElementException:
        name.append('None')
    
    # fetching varient of used cars
    try:
        car_varient = driver.find_elements(By.XPATH,"//div[@class='variant-name']")
        for car_v in car_varient:
            varient.append(car_v.text)
    except NoSuchElementException:
        varient.append('None')
        
    # fetching engine type driven of used cars
    try:
        engine_type = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[3]/div/div[2]")
        for engines in engine_type:
            engine.append(engines.text)
    except NoSuchElementException:
        engine.append('None')
        
    # fetching kilometers driven of used cars
    try:
        kilo_d= driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[4]/div/div[2]")
        for kilo in kilo_d:
            kilometers.append(kilo.text)
    except NoSuchElementException:
        kilometers.append('None')
        
    # fetching car_type details of used cars
    try:
        car_t = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[8]/div/div[2]")
        for types in car_t:
            car_type.append(types.text)
    except NoSuchElementException:
        car_type.append('None')
        
    # fetching owner details of used cars
    try:
        no_of_owner = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[6]/div/div[2]")
        for owners in no_of_owner:
            owner.append(owners.text)
    except NoSuchElementException:
        owner.append('None')
        
    # fetching year of used cars
    try:
        years = driver.find_elements(By.XPATH,"//ul[@class='gsc_row detailsList']/li[1]/div/div[2]")
        for loc in years:
            year.append(loc.text)
    except NoSuchElementException:
        year.append('None')
        
    # fetching price of used cars
    try:
        prices = driver.find_elements(By.XPATH,"//div[@class='priceSection']")
        for pri in prices:
            price.append(pri.text)
    except NoSuchElementException:
        price.append('None')
        
        
#dataframe
df7 = pd.DataFrame({})
df7["name"] = name
df7["varient"] = varient
df7["engine"] = engine
df7["kilometers"] = kilometers
df7["car_type"] = car_type
df7["location"] = location
df7["year"]=year
df7["price"] = price

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7])

# %%
# Saving the data into excel file
df.to_excel("Used_Cars.xlsx")
